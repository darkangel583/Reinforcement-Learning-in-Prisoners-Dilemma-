# %%
# !pip3 install axelrod==4.11.0
# Out:
# Collecting axelrod==4.11.0
#   Downloading Axelrod-4.11.0.tar.gz (205 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 205.3/205.3 kB 4.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: cloudpickle>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from axelrod==4.11.0) (2.2.1)
# Requirement already satisfied: fsspec>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from axelrod==4.11.0) (2023.6.0)
# Requirement already satisfied: toolz>=0.8.2 in /usr/local/lib/python3.10/dist-packages (from axelrod==4.11.0) (0.12.1)
# Requirement already satisfied: dask>=2.9.2 in /usr/local/lib/python3.10/dist-packages (from axelrod==4.11.0) (2023.8.1)
# Requirement already satisfied: matplotlib>=3.0.3 in /usr/local/lib/python3.10/dist-packages (from axelrod==4.11.0) (3.7.1)
# Requirement already satisfied: numpy>=1.17.4 in /usr/local/lib/python3.10/dist-packages (from axelrod==4.11.0) (1.25.2)
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from axelrod==4.11.0) (1.5.3)
# Requirement already satisfied: prompt-toolkit>=3.0 in /usr/local/lib/python3.10/dist-packages (from axelrod==4.11.0) (3.0.43)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from axelrod==4.11.0) (6.0.1)
# Requirement already satisfied: scipy>=1.3.3 in /usr/local/lib/python3.10/dist-packages (from axelrod==4.11.0) (1.11.4)
# Requirement already satisfied: tqdm>=4.39.0 in /usr/local/lib/python3.10/dist-packages (from axelrod==4.11.0) (4.66.2)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.10/dist-packages (from dask>=2.9.2->axelrod==4.11.0) (8.1.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from dask>=2.9.2->axelrod==4.11.0) (23.2)
# Requirement already satisfied: partd>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from dask>=2.9.2->axelrod==4.11.0) (1.4.1)
# Requirement already satisfied: importlib-metadata>=4.13.0 in /usr/local/lib/python3.10/dist-packages (from dask>=2.9.2->axelrod==4.11.0) (7.0.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.3->axelrod==4.11.0) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.3->axelrod==4.11.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.3->axelrod==4.11.0) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.3->axelrod==4.11.0) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.3->axelrod==4.11.0) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.3->axelrod==4.11.0) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.3->axelrod==4.11.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.0->axelrod==4.11.0) (2023.4)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit>=3.0->axelrod==4.11.0) (0.2.13)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=4.13.0->dask>=2.9.2->axelrod==4.11.0) (3.17.0)
# Requirement already satisfied: locket in /usr/local/lib/python3.10/dist-packages (from partd>=1.2.0->dask>=2.9.2->axelrod==4.11.0) (1.0.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.0.3->axelrod==4.11.0) (1.16.0)
# Building wheels for collected packages: axelrod
#   Building wheel for axelrod (setup.py) ... done
#   Created wheel for axelrod: filename=Axelrod-4.11.0-py2.py3-none-any.whl size=191298 sha256=34a37522d6e5a623f42ac822b992684894f53f5632835c356943f781de80baf3
#   Stored in directory: /root/.cache/pip/wheels/af/02/89/cf954fed58b376279061979389ba6808c9f22ad1accccdadd9
# Successfully built axelrod
# Installing collected packages: axelrod
# Successfully installed axelrod-4.11.0

# %% [markdown]
# # **Normal Q-Learning Tournament**

# %%
import axelrod as axl
import pandas as pd
import numpy as np

# Define the strategies you want to include in the tournament
strategies = [
    axl.Cooperator(),
    axl.Defector(),
    axl.TitForTat(),
    axl.Grudger(),
    axl.Random(),
    axl.AntiTitForTat(),
    axl.SecondByChampion(),
    axl.Gradual(),
    axl.AdaptiveTitForTat(),
    axl.Cycler("CDCD"),
    axl.Calculator(),
    axl.CycleHunter(),
    axl.Pi(),
]

# Create a tournament with the specified strategies
tournament = axl.Tournament(players=strategies, turns=200, repetitions=10)

# Run the tournament
results = tournament.play()

# Convert scores to a NumPy array
scores_array = np.array(results.scores)

# Calculate mean and median scores for each strategy
mean_scores = np.mean(scores_array, axis=1)
median_scores = np.median(scores_array, axis=1)

# Create a DataFrame
df = pd.DataFrame({
    "Strategy": results.ranked_names,
    "Mean Score": mean_scores,
    "Median Score": median_scores
})

# Sort the DataFrame by "Mean Score" in descending order
df = df.sort_values(by="Mean Score", ascending=False)

# Display the DataFrame
print(df)
# Out:
# Playing matches: 100%|██████████| 91/91 [00:02<00:00, 32.93it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 51.63it/s]
#                      Strategy  Mean Score  Median Score
# 3                  Calculator      7184.0        7186.0
# 7          Second by Champion      7011.1        7070.5
# 1                     Gradual      6496.0        6502.0
# 10               Cycler: CDCD      6217.1        6140.0
# 8                 Random: 0.5      6051.6        5983.0
# 2                    Defector      6025.6        5981.5
# 5                 Tit For Tat      5787.5        5908.0
# 6            Anti Tit For Tat      5772.5        5866.0
# 4   Adaptive Tit For Tat: 0.5      5492.4        5619.5
# 12                 Cooperator      5347.0        5345.5
# 9                       $\pi$      4750.3        4752.5
# 11               Cycle Hunter      4612.7        4563.0
# 0                     Grudger      4250.4        4249.5

# %% [markdown]
# # **Q - Learning**

# %%
import axelrod as axl

# %%
import numpy as np
import random

# %%
C = axl.Action.C
D = axl.Action.D

# %%
class TitForTat(axl.Player):
    """
    A player starts by cooperating and then mimics the previous action of the
    opponent.

    This strategy was referred to as the *'simplest'* strategy submitted to
    Axelrod's first tournament. It came first.

    Note that the code for this strategy is written in a fairly verbose
    way. This is done so that it can serve as an example strategy for
    those who might be new to Python.

    Names:

    - Rapoport's strategy: [Axelrod1980]_
    - TitForTat: [Axelrod1980]_
    """

    # These are various properties for the strategy
    name = "Tit For Tat"
    classifier = {
        "memory_depth": 1,  # Four-Vector = (1.,0.,1.,0.)
        "stochastic": False,
        "long_run_time": False,
        "inspects_source": False,
        "manipulates_source": False,
        "manipulates_state": False,
    }
    def strategy(self, opponent):
        """This is the actual strategy"""
        # First move
        if not self.history:
            return C
        # React to the opponent's last move
        print(opponent.history[-1])
        if opponent.history[-1][0] == D:
            return D
        return C

# %%
import operator
class QLearningAgent(axl.Player):
    # Actions possible
    actions = [C,D]
    # History of self actions
    history = []

    def __init__(self, learning_rate, discount_factor, exploration_prob):
        super().__init__()
        self.learning_rate = learning_rate
        self.discount_factor = discount_factor
        self.exploration_prob = exploration_prob
        self.q_table = {}
        # for s in [((C, C),), ((C, D),), ((D, C),), ((D, D),)]:
        #   for a in [C,D]:
        #     self.q_table[(s,a)] = 0

        #self.q_table[((C,D),),C]=1
        # for s in [C,D]:
        #   self.q_table[s]=0

        #self.q_table[D]=0.1
        self.last_action = None

    # Reward
    # C:C -> 50, C:D -> -100, D:C -> 100, D:D -> -50
    def reward(self, state, action):
        s=action
        o=state[0][1]

        if s == C:
            return 50 if o == C else -100
        else:
            return 100 if o == C else -50

    # Q-table
    def update_q_table(self, state, action, reward, next_state, opponent):

        """
        Update the Q-values in the Q-table based on the observed reward and next state.
        """
        #print(state)
        #print(action)
        current_q = self.q_table.get((state,action),0)
        #print(current_q)  # Get the current Q-value for the state-action pair
        # Calculate the new Q-value using the Bellman equation
        max_future_q = max([self.q_table.get(((next_state,),a),0) for a in (C, D)])
        #print(max_future_q) # Max Q-value for next state
        #new_q = (1 - self.learning_rate) * current_q + self.learning_rate * (reward(self.last_action, opponent.last_action) + self.discount_factor * max_future_q)
        #print(reward(state,action))
        new_q = (1 - self.learning_rate) * current_q + self.learning_rate * (reward(state, action) + self.discount_factor * max_future_q)
        #print(new_q)
        #print(state)
        #print(action)
        self.q_table[(state, action)] = new_q  # Update the Q-value in the Q-table

    # def update(self,opponent):
    #   print("HEllo")
    #   state=(self.history[-1],)
    #   action=self.last_action

    #   next_state=(action,opponent.history[-1])

    #   self.update_q_table(state,action,self.reward,next_state,opponent)


    def strategy(self, opponent):
        if not self.history:
            return C
        #print(history)
        action=self.last_action
        if action==None:
          action=D

        state = (self.history[-1],)  # Get the current state
        next_state=(action,opponent.history[-1])


        self.update_q_table(state,action,self.reward,next_state,opponent)

        if random.random() < self.exploration_prob:
            action = random.choice([C, D])
            #print(action)
        else:
            # Choose action based on Q-values
            #print(self.q_table)
            action = max(self.q_table.items(), key=operator.itemgetter(1))[0][1]
            #print(action)

        # Update action for the next round
        self.last_action = action
        return action

    def update_history(self, play, coplay):
        """
        Update the QLearningAgent's history with their action and their coplayer's action.
        """
        self.history.append((play, coplay))
        #print((play, coplay))
        #self.history=list(zip(*self.history))

player1 = TitFor2Tats()
player2 = TitForTat()
#Create a match with the QLearningAgent player
match = axl.Match(players=[QLearningAgent(learning_rate=0.5, discount_factor=0.9, exploration_prob=0.1), player2],turns=100)

# Run the tournament
results = match.play()
# # Display the results
print(results)

print(match.final_score())
# Out:
# (C, C)
# (D, C)
# (D, D)
# (D, D)
# (D, D)
# (D, D)
# (D, D)
# (D, D)
# (D, D)
# (D, D)
# (D, D)
# (D, D)
# (D, D)
# (D, D)
# (D, D)
# (D, D)
# (D, D)
# (D, D)
# (D, D)
# (C, D)
# (C, C)
# (D, C)
# (D, D)
# (D, D)
# (C, D)
# (D, C)
# (D, D)
# (D, D)
# (D, D)
# (D, D)
# (D, D)
# (D, D)
# (D, D)
# (D, D)
# (D, D)
# (D, D)
# (D, D)
# (D, D)
# (D, D)
# (D, D)
# (D, D)
# (D, D)
# (D, D)
# (D, D)
# (D, D)
# (D, D)
# (D, D)
# (D, D)
# (D, D)
# (D, D)
# (D, D)
# (D, D)
# (D, D)
# (D, D)
# (C, D)
# (D, C)
# (D, D)
# (D, D)
# (D, D)
# (D, D)
# (D, D)
# (D, D)
# (D, D)
# (D, D)
# (D, D)
# (D, D)
# (D, D)
# (D, D)
# (D, D)
# (D, D)
# (D, D)
# (D, D)
# (D, D)
# (D, D)
# (D, D)
# (D, D)
# (D, D)
# (C, D)
# (D, C)
# (D, D)
# (D, D)
# (D, D)
# (D, D)
# (D, D)
# (D, D)
# (D, D)
# (D, D)
# (D, D)
# (D, D)
# (D, D)
# (D, D)
# (D, D)
# (D, D)
# (D, D)
# (D, D)
# (D, D)
# (D, D)
# (D, D)
# (D, D)
# [(C, C), (D, C), (D, D), (D, D), (D, D), (D, D), (D, D), (D, D), (D, D), (D, D), (D, D), (D, D), (D, D), (D, D), (D, D), (D, D), (D, D), (D, D), (D, D), (C, D), (C, C), (D, C), (D, D), (D, D), (C, D), (D, C), (D, D), (D, D), (D, D), (D, D), (D, D), (D, D), (D, D), (D, D), (D, D), (D, D), (D, D), (D, D), (D, D), (D, D), (D, D), (D, D), (D, D), (D, D), (D, D), (D, D), (D, D), (D, D), (D, D), (D, D), (D, D), (D, D), (D, D), (D, D), (C, D), (D, C), (D, D), (D, D), (D, D), (D, D), (D, D), (D, D), (D, D), (D, D), (D, D), (D, D), (D, D), (D, D), (D, D), (D, D), (D, D), (D, D), (D, D), (D, D), (D, D), (D, D), (D, D), (C, D), (D, C), (D, D), (D, D), (D, D), (D, D), (D, D), (D, D), (D, D), (D, D), (D, D), (D, D), (D, D), (D, D), (D, D), (D, D), (D, D), (D, D), (D, D), (D, D), (D, D), (D, D), (D, D)]
# (120, 115)

# %% [markdown]
# # **DQN**

# %%
import tensorflow as tf

# %%
#history = []
C = axl.Action.C
D = axl.Action.D

class DQNAgent(axl.Player):
    history=[]
    def __init__(self, learning_rate, discount_factor, exploration_prob):
      super().__init__()
      self.learning_rate = learning_rate
      self.discount_factor = discount_factor
      self.exploration_prob = exploration_prob
      self.model = self._build_model()
      self.memory = []
      self.last_action = None
      self.agent_history = []  # Initialize agent history

    def _build_model(self):
        model = tf.keras.Sequential([
            tf.keras.layers.Dense(24, input_dim=4, activation='relu'),
            tf.keras.layers.Dense(24, activation='relu'),
            tf.keras.layers.Dense(2, activation='linear')
        ])
        model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=self.learning_rate),
                      loss='mse')
        return model

    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def choose_action(self, state):
        #print("hello")
        if np.random.rand() <= self.exploration_prob:
            return random.choice([C, D])
        else:
            #print(q_values)
            q_values = self.model.predict(state)
            #print(q_values)
            if np.argmax(q_values[0])==0:
              return C
            else:
              return D

    def replay(self, batch_size):
        minibatch = random.sample(self.memory, batch_size)
        for state, action, reward, next_state, done in minibatch:
            target = reward
            if not done:
                target = reward + self.discount_factor * np.amax(self.model.predict(next_state)[0])
            target_f = self.model.predict(state)
            target_f[0][action] = target
            self.model.fit(state, target_f, epochs=1, verbose=0)

    def update_history(self, play, coplay):
        """
        Update the QLearningAgent's history with their action and their coplayer's action.
        """
        self.history.append((play, coplay))

    def strategy(self, opponent):
        if self.history==[]:
            #print("Hello")
            return C

        #print("Hello")

        action=self.last_action
        if action==None:
          action=C


        state = (self.history[-1],)  # Get the current state
        next_state=(action,opponent.history[-1])

        if random.random() < self.exploration_prob:
            action = random.choice([C, D])
        else:
            #print(self.history[-1])
            state = np.array([self._encode_state(self.history[-1])])
            action = self.choose_action(state)

        self.last_action = action
        self.remember(state, action, self.reward(action, opponent.history[-1]), np.array([self._encode_state((action, opponent.history[-1]))]), False)

        return action

    def reward(self, action, coplay):
        """
        Define rewards based on the agent's action and its coplayer's action.
        """
        rewards = {
            (C, C): 50,
            (C, D): -100,
            (D, C): 100,
            (D, D): -50
        }
        return rewards[(action, coplay)]

    def _encode_state(self, state):
        """
        Encode the current state for the neural network input.
        """
        state_mapping = {
            (C, C): [1, 0, 0, 0],
            (C, D): [0, 1, 0, 0],
            (D, C): [0, 0, 1, 0],
            (D, D): [0, 0, 0, 1]
        }
        return state_mapping[state]

# Create a match with the DQNAgent player
agent = axl.Player()


player1 = TitForTat()
match = axl.Match(players=[DQNAgent(learning_rate=0.1, discount_factor=0.7, exploration_prob=0.3), player1],turns=100)

# Run the tournament
results = match.play()

# Display the results
print(results)
print(match.final_score())
# Out:
# 1/1 [==============================] - 0s 135ms/step
# (C, C)
# 1/1 [==============================] - 0s 19ms/step
# (C, C)
# (C, C)
# (D, C)
# (D, D)
# 1/1 [==============================] - 0s 25ms/step
# (D, D)
# (D, D)
# 1/1 [==============================] - 0s 20ms/step
# (D, D)
# (D, D)
# 1/1 [==============================] - 0s 20ms/step
# (D, D)
# 1/1 [==============================] - 0s 25ms/step
# (D, D)
# 1/1 [==============================] - 0s 20ms/step
# (D, D)
# 1/1 [==============================] - 0s 20ms/step
# (D, D)
# (D, D)
# (C, D)
# 1/1 [==============================] - 0s 19ms/step
# (C, C)
# 1/1 [==============================] - 0s 19ms/step
# (C, C)
# 1/1 [==============================] - 0s 19ms/step
# (C, C)
# (C, C)
# (C, C)
# 1/1 [==============================] - 0s 23ms/step
# (C, C)
# (C, C)
# 1/1 [==============================] - 0s 20ms/step
# (C, C)
# 1/1 [==============================] - 0s 29ms/step
# (C, C)
# 1/1 [==============================] - 0s 20ms/step
# (C, C)
# (C, C)
# (D, C)
# (C, D)
# (D, C)
# 1/1 [==============================] - 0s 21ms/step
# (C, D)
# (C, C)
# 1/1 [==============================] - 0s 19ms/step
# (D, C)
# 1/1 [==============================] - 0s 20ms/step
# (D, D)
# (D, D)
# (C, D)
# 1/1 [==============================] - 0s 23ms/step
# (D, C)
# (D, D)
# 1/1 [==============================] - 0s 22ms/step
# (C, D)
# (C, C)
# (D, C)
# 1/1 [==============================] - 0s 23ms/step
# (D, D)
# 1/1 [==============================] - 0s 21ms/step
# (D, D)
# 1/1 [==============================] - 0s 20ms/step
# (D, D)
# 1/1 [==============================] - 0s 23ms/step
# (D, D)
# (D, D)
# 1/1 [==============================] - 0s 25ms/step
# (D, D)
# 1/1 [==============================] - 0s 45ms/step
# (D, D)
# 1/1 [==============================] - 0s 31ms/step
# (D, D)
# 1/1 [==============================] - 0s 38ms/step
# (D, D)
# 1/1 [==============================] - 0s 37ms/step
# (D, D)
# (D, D)
# 1/1 [==============================] - 0s 32ms/step
# (D, D)
# (D, D)
# 1/1 [==============================] - 0s 34ms/step
# (C, D)
# 1/1 [==============================] - 0s 49ms/step
# (C, C)
# (C, C)
# (D, C)
# 1/1 [==============================] - 0s 31ms/step
# (C, D)
# (C, C)
# (C, C)
# 1/1 [==============================] - 0s 38ms/step
# (D, C)
# 1/1 [==============================] - 0s 38ms/step
# (D, D)
# 1/1 [==============================] - 0s 31ms/step
# (D, D)
# (D, D)
# (D, D)
# (C, D)
# (D, C)
# (C, D)
# (C, C)
# (D, C)
# 1/1 [==============================] - 0s 35ms/step
# (C, D)
# 1/1 [==============================] - 0s 33ms/step
# (C, C)
# 1/1 [==============================] - 0s 34ms/step
# (C, C)
# 1/1 [==============================] - 0s 32ms/step
# (C, C)
# 1/1 [==============================] - 0s 38ms/step
# (C, C)
# (C, C)
# (C, C)
# 1/1 [==============================] - 0s 32ms/step
# (D, C)
# 1/1 [==============================] - 0s 33ms/step
# (D, D)
# 1/1 [==============================] - 0s 37ms/step
# (D, D)
# (D, D)
# 1/1 [==============================] - 0s 32ms/step
# (D, D)
# (D, D)
# (D, D)
# (C, D)
# (C, C)
# (D, C)
# 1/1 [==============================] - 0s 20ms/step
# (C, D)
# (C, C)
# 1/1 [==============================] - 0s 20ms/step
# (C, C)
# (C, C)
# (D, C)
# 1/1 [==============================] - 0s 21ms/step
# (D, D)
# (D, D)
# (C, D)
# (C, C)
# (C, C)
# (D, C)
# (D, D)
# [(C, C), (C, C), (C, C), (D, C), (D, D), (D, D), (D, D), (D, D), (D, D), (D, D), (D, D), (D, D), (D, D), (D, D), (C, D), (C, C), (C, C), (C, C), (C, C), (C, C), (C, C), (C, C), (C, C), (C, C), (C, C), (C, C), (D, C), (C, D), (D, C), (C, D), (C, C), (D, C), (D, D), (D, D), (C, D), (D, C), (D, D), (C, D), (C, C), (D, C), (D, D), (D, D), (D, D), (D, D), (D, D), (D, D), (D, D), (D, D), (D, D), (D, D), (D, D), (D, D), (D, D), (C, D), (C, C), (C, C), (D, C), (C, D), (C, C), (C, C), (D, C), (D, D), (D, D), (D, D), (D, D), (C, D), (D, C), (C, D), (C, C), (D, C), (C, D), (C, C), (C, C), (C, C), (C, C), (C, C), (C, C), (D, C), (D, D), (D, D), (D, D), (D, D), (D, D), (D, D), (C, D), (C, C), (D, C), (C, D), (C, C), (C, C), (C, C), (D, C), (D, D), (D, D), (C, D), (C, C), (C, C), (D, C), (D, D), (C, D)]
# (208, 208)

# %% [markdown]
# # **Tournament**

# %% [markdown]
# # **Examples**

# %%
import numpy as np

class ProfitAgent:
    def __init__(self, epsilon=0.1, learning_rate=0.1, discount_factor=0.95):
        self.epsilon = epsilon  # Exploration rate
        self.learning_rate = learning_rate  # Learning rate
        self.discount_factor = discount_factor  # Discount factor for future rewards
        self.q_values = {}  # Q-values dictionary

    def choose_action(self, state):
        if np.random.rand() < self.epsilon:
            # Explore: choose a random action
            return np.random.choice([0, 1])  # 0: no advertising, 1: advertising
        else:
            # Exploit: choose the action with the highest Q-value
            return np.argmax(self.q_values.get(state, [0, 0]))  # 0: no advertising, 1: advertising

    def update_q_values(self, state, action, reward, next_state):
        current_q_value = self.q_values.get(state, [0, 0])[action]
        next_max_q_value = np.max(self.q_values.get(next_state, [0, 0]))
        new_q_value = current_q_value + self.learning_rate * (reward + self.discount_factor * next_max_q_value - current_q_value)
        self.q_values[state] = [0, 0]
        self.q_values[state][action] = new_q_value

def simulate_competition(num_episodes=1000):
    agent_coca_cola = ProfitAgent()
    agent_pepsi = ProfitAgent()

    for _ in range(num_episodes):
        # State: combination of actions (0: no advertising, 1: advertising) of both companies
        state_coca_cola = tuple([agent_coca_cola.choose_action(())])
        state_pepsi = tuple([agent_pepsi.choose_action(())])

        # Let's simplify the reward function: both companies get a reward of 1 if they both advertise, 0 otherwise
        if state_coca_cola[0] == 1 and state_pepsi[0] == 1:
            reward_coca_cola = 1
            reward_pepsi = 1
        else:
            reward_coca_cola = 0
            reward_pepsi = 0

        agent_coca_cola.update_q_values(state_coca_cola, state_coca_cola[0], reward_coca_cola, ())
        agent_pepsi.update_q_values(state_pepsi, state_pepsi[0], reward_pepsi, ())

    return agent_coca_cola.q_values, agent_pepsi.q_values

# Simulate the competition
coca_cola_q_values, pepsi_q_values = simulate_competition()

# Display the Q-values learned by each company
print("Coca-Cola Q-values:", coca_cola_q_values)
print("Pepsi Q-values:", pepsi_q_values)
# Out:
# Coca-Cola Q-values: {(0,): [0.0, 0], (1,): [0, 0.039939300418256204]}
# Pepsi Q-values: {(0,): [0.0, 0], (1,): [0, 0.05539693995449392]}

# %%
import numpy as np

class ProfitAgent:
    def __init__(self, epsilon=0.1, learning_rate=0.1, discount_factor=0.95):
        self.epsilon = epsilon  # Exploration rate
        self.learning_rate = learning_rate  # Learning rate
        self.discount_factor = discount_factor  # Discount factor for future rewards
        self.q_values = {}  # Q-values dictionary

    def choose_action(self, state):
        if np.random.rand() < self.epsilon:
            # Explore: choose a random action
            return np.random.choice([0, 1])  # 0: cooperate (C), 1: defect (D)
        else:
            # Exploit: choose the action with the highest Q-value
            return np.argmax(self.q_values.get(state, [0, 0]))  # 0: cooperate (C), 1: defect (D)

    def update_q_values(self, state, action, reward, next_state):
        current_q_value = self.q_values.get(state, [0, 0])[action]
        next_max_q_value = np.max(self.q_values.get(next_state, [0, 0]))
        new_q_value = current_q_value + self.learning_rate * (reward + self.discount_factor * next_max_q_value - current_q_value)
        self.q_values[state] = [0, 0]
        self.q_values[state][action] = new_q_value

def simulate_competition(num_episodes=1000):
    agent_coca_cola = ProfitAgent()
    agent_pepsi = ProfitAgent()

    coca_cola_profit = 100
    pepsi_profit = 100

    for _ in range(num_episodes):
        state_coca_cola = tuple([agent_coca_cola.choose_action(())])
        state_pepsi = tuple([agent_pepsi.choose_action(())])

        if state_coca_cola[0] == state_pepsi[0]:  # Both companies take the same action
            if state_coca_cola[0] == 0:  # Both cooperate (C)
                reward_coca_cola = 5
                reward_pepsi = 5
            else:  # Both defect (D)
                reward_coca_cola = -5
                reward_pepsi = -5
        else:  # Different actions
            if state_coca_cola[0] == 0:  # Coca-Cola cooperates (C), Pepsi defects (D)
                reward_coca_cola = 5
                reward_pepsi = -5
            else:  # Coca-Cola defects (D), Pepsi cooperates (C)
                reward_coca_cola = -5
                reward_pepsi = 5

        # Update profits
        coca_cola_profit += reward_coca_cola
        pepsi_profit += reward_pepsi

        agent_coca_cola.update_q_values(state_coca_cola, state_coca_cola[0], reward_coca_cola, ())
        agent_pepsi.update_q_values(state_pepsi, state_pepsi[0], reward_pepsi, ())

    return coca_cola_profit, pepsi_profit

# Simulate the competition
coca_cola_profit, pepsi_profit = simulate_competition()

# Display the profits of Coca-Cola and Pepsi
print("Coca-Cola Profit:", coca_cola_profit)
print("Pepsi Profit:", pepsi_profit)
# Out:
# Coca-Cola Profit: 4640
# Pepsi Profit: 4560

# %% [markdown]
# # **Q-Learning **
#
# Here we depict the profit margin competition between COCO-COLA vs Pepsi where both companies are represented by Q-learning

# %%
import numpy as np

class ProfitAgent:
    def __init__(self, name, epsilon=0.1, learning_rate=0.1, discount_factor=0.95):
        self.name = name
        self.epsilon = epsilon
        self.learning_rate = learning_rate
        self.discount_factor = discount_factor
        self.q_values = {}
        self.wins = 0  # Initialize win count to zero

    def choose_action(self, state):
        if np.random.rand() < self.epsilon:
            return np.random.choice(['C', 'D'])
        else:
            state_q_values = self.q_values.get(state)
            if state_q_values is None:
                # Initialize Q-values for the state
                self.q_values[state] = {'C': 0, 'D': 0}
                state_q_values = self.q_values[state]
            return max(state_q_values, key=state_q_values.get)

    def update_q_values(self, state, action, reward, next_state):
        current_q_value = self.q_values.get(state, {'C': 0, 'D': 0})[action]
        next_max_q_value = max(self.q_values.get(next_state, {'C': 0, 'D': 0}).values())
        new_q_value = current_q_value + self.learning_rate * (
                    reward + self.discount_factor * next_max_q_value - current_q_value)
        self.q_values[state] = {'C': 0, 'D': 0}
        self.q_values[state][action] = new_q_value

    def record_win(self):
        self.wins += 1  # Increment win count

def simulate_competition(num_episodes=1000):
    coca_cola = ProfitAgent(name='Coca-Cola')
    pepsi = ProfitAgent(name='Pepsi')

    coca_cola_profit = 100
    pepsi_profit = 100

    for episode in range(1, num_episodes + 1):
        state_coca_cola = ()
        state_pepsi = ()

        action_coca_cola = coca_cola.choose_action(state_coca_cola)
        action_pepsi = pepsi.choose_action(state_pepsi)

        if action_coca_cola == action_pepsi:
            reward_coca_cola = 5 if action_coca_cola == 'C' else -5
            reward_pepsi = 5 if action_pepsi == 'C' else -5
        elif action_coca_cola == 'C':
            reward_coca_cola = -10
            reward_pepsi = 10
        else:
            reward_coca_cola = 10
            reward_pepsi = -10

        coca_cola_profit += reward_coca_cola
        pepsi_profit += reward_pepsi

        coca_cola.update_q_values(state_coca_cola, action_coca_cola, reward_coca_cola, state_coca_cola)
        pepsi.update_q_values(state_pepsi, action_pepsi, reward_pepsi, state_pepsi)

        # Determine the winner of the episode and record the win
        if coca_cola_profit > pepsi_profit:
            coca_cola.record_win()
        elif pepsi_profit > coca_cola_profit:
            pepsi.record_win()

        print(f"Episode {episode}: Coca-Cola Action: {action_coca_cola}, Pepsi Action: {action_pepsi}, "
              f"Coca-Cola Profit: {coca_cola_profit}, Pepsi Profit: {pepsi_profit}")

    return coca_cola.q_values, pepsi.q_values, coca_cola.wins, pepsi.wins

# Simulate the competition
coca_cola_q_values, pepsi_q_values, coca_cola_wins, pepsi_wins = simulate_competition()

# Display the Q-values learned by each company
print("Coca-Cola Q-values:", coca_cola_q_values)
print("Pepsi Q-values:", pepsi_q_values)

# Display the number of wins for each company
print("Coca-Cola Wins:", coca_cola_wins)
print("Pepsi Wins:", pepsi_wins)
# Out:
# Episode 1: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 105, Pepsi Profit: 105
# Episode 2: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 110, Pepsi Profit: 110
# Episode 3: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 115, Pepsi Profit: 115
# Episode 4: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 120, Pepsi Profit: 120
# Episode 5: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 125, Pepsi Profit: 125
# Episode 6: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 130, Pepsi Profit: 130
# Episode 7: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 135, Pepsi Profit: 135
# Episode 8: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 140, Pepsi Profit: 140
# Episode 9: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 145, Pepsi Profit: 145
# Episode 10: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 150, Pepsi Profit: 150
# Episode 11: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 155, Pepsi Profit: 155
# Episode 12: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: 165, Pepsi Profit: 145
# Episode 13: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: 175, Pepsi Profit: 135
# Episode 14: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: 170, Pepsi Profit: 130
# Episode 15: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: 165, Pepsi Profit: 125
# Episode 16: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: 175, Pepsi Profit: 115
# Episode 17: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: 170, Pepsi Profit: 110
# Episode 18: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: 180, Pepsi Profit: 100
# Episode 19: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: 170, Pepsi Profit: 110
# Episode 20: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: 165, Pepsi Profit: 105
# Episode 21: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: 155, Pepsi Profit: 115
# Episode 22: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: 150, Pepsi Profit: 110
# Episode 23: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: 140, Pepsi Profit: 120
# Episode 24: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: 135, Pepsi Profit: 115
# Episode 25: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: 125, Pepsi Profit: 125
# Episode 26: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: 120, Pepsi Profit: 120
# Episode 27: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 125, Pepsi Profit: 125
# Episode 28: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: 135, Pepsi Profit: 115
# Episode 29: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: 130, Pepsi Profit: 110
# Episode 30: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: 140, Pepsi Profit: 100
# Episode 31: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: 135, Pepsi Profit: 95
# Episode 32: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 140, Pepsi Profit: 100
# Episode 33: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 145, Pepsi Profit: 105
# Episode 34: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: 135, Pepsi Profit: 115
# Episode 35: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: 125, Pepsi Profit: 125
# Episode 36: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: 120, Pepsi Profit: 120
# Episode 37: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: 110, Pepsi Profit: 130
# Episode 38: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: 105, Pepsi Profit: 125
# Episode 39: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: 95, Pepsi Profit: 135
# Episode 40: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: 85, Pepsi Profit: 145
# Episode 41: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: 80, Pepsi Profit: 140
# Episode 42: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: 70, Pepsi Profit: 150
# Episode 43: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: 65, Pepsi Profit: 145
# Episode 44: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: 55, Pepsi Profit: 155
# Episode 45: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: 50, Pepsi Profit: 150
# Episode 46: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: 40, Pepsi Profit: 160
# Episode 47: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: 30, Pepsi Profit: 170
# Episode 48: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: 25, Pepsi Profit: 165
# Episode 49: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: 15, Pepsi Profit: 175
# Episode 50: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: 10, Pepsi Profit: 170
# Episode 51: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: 0, Pepsi Profit: 180
# Episode 52: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -5, Pepsi Profit: 175
# Episode 53: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -15, Pepsi Profit: 185
# Episode 54: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -20, Pepsi Profit: 180
# Episode 55: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -30, Pepsi Profit: 190
# Episode 56: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -35, Pepsi Profit: 185
# Episode 57: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -45, Pepsi Profit: 195
# Episode 58: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -50, Pepsi Profit: 190
# Episode 59: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -60, Pepsi Profit: 200
# Episode 60: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -65, Pepsi Profit: 195
# Episode 61: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -75, Pepsi Profit: 205
# Episode 62: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -80, Pepsi Profit: 200
# Episode 63: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -90, Pepsi Profit: 210
# Episode 64: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -95, Pepsi Profit: 205
# Episode 65: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -100, Pepsi Profit: 200
# Episode 66: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -110, Pepsi Profit: 210
# Episode 67: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -115, Pepsi Profit: 205
# Episode 68: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -125, Pepsi Profit: 215
# Episode 69: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: -115, Pepsi Profit: 205
# Episode 70: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -120, Pepsi Profit: 200
# Episode 71: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: -110, Pepsi Profit: 190
# Episode 72: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -115, Pepsi Profit: 185
# Episode 73: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -110, Pepsi Profit: 190
# Episode 74: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -105, Pepsi Profit: 195
# Episode 75: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -100, Pepsi Profit: 200
# Episode 76: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -95, Pepsi Profit: 205
# Episode 77: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -90, Pepsi Profit: 210
# Episode 78: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -85, Pepsi Profit: 215
# Episode 79: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -80, Pepsi Profit: 220
# Episode 80: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -75, Pepsi Profit: 225
# Episode 81: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -85, Pepsi Profit: 235
# Episode 82: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -95, Pepsi Profit: 245
# Episode 83: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -105, Pepsi Profit: 255
# Episode 84: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -115, Pepsi Profit: 265
# Episode 85: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -120, Pepsi Profit: 260
# Episode 86: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -130, Pepsi Profit: 270
# Episode 87: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -135, Pepsi Profit: 265
# Episode 88: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -145, Pepsi Profit: 275
# Episode 89: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -150, Pepsi Profit: 270
# Episode 90: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -160, Pepsi Profit: 280
# Episode 91: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -165, Pepsi Profit: 275
# Episode 92: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -175, Pepsi Profit: 285
# Episode 93: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -180, Pepsi Profit: 280
# Episode 94: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -190, Pepsi Profit: 290
# Episode 95: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: -180, Pepsi Profit: 280
# Episode 96: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -185, Pepsi Profit: 275
# Episode 97: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: -175, Pepsi Profit: 265
# Episode 98: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -180, Pepsi Profit: 260
# Episode 99: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: -170, Pepsi Profit: 250
# Episode 100: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -175, Pepsi Profit: 245
# Episode 101: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: -165, Pepsi Profit: 235
# Episode 102: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -170, Pepsi Profit: 230
# Episode 103: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -165, Pepsi Profit: 235
# Episode 104: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -160, Pepsi Profit: 240
# Episode 105: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -155, Pepsi Profit: 245
# Episode 106: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -150, Pepsi Profit: 250
# Episode 107: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -145, Pepsi Profit: 255
# Episode 108: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -140, Pepsi Profit: 260
# Episode 109: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -135, Pepsi Profit: 265
# Episode 110: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -130, Pepsi Profit: 270
# Episode 111: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -125, Pepsi Profit: 275
# Episode 112: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -120, Pepsi Profit: 280
# Episode 113: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -115, Pepsi Profit: 285
# Episode 114: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -110, Pepsi Profit: 290
# Episode 115: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -105, Pepsi Profit: 295
# Episode 116: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -100, Pepsi Profit: 300
# Episode 117: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -110, Pepsi Profit: 310
# Episode 118: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -120, Pepsi Profit: 320
# Episode 119: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -130, Pepsi Profit: 330
# Episode 120: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -135, Pepsi Profit: 325
# Episode 121: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -145, Pepsi Profit: 335
# Episode 122: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -150, Pepsi Profit: 330
# Episode 123: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -160, Pepsi Profit: 340
# Episode 124: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -165, Pepsi Profit: 335
# Episode 125: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -175, Pepsi Profit: 345
# Episode 126: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -180, Pepsi Profit: 340
# Episode 127: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -190, Pepsi Profit: 350
# Episode 128: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -195, Pepsi Profit: 345
# Episode 129: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -205, Pepsi Profit: 355
# Episode 130: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -210, Pepsi Profit: 350
# Episode 131: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -220, Pepsi Profit: 360
# Episode 132: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -225, Pepsi Profit: 355
# Episode 133: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -235, Pepsi Profit: 365
# Episode 134: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -245, Pepsi Profit: 375
# Episode 135: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -250, Pepsi Profit: 370
# Episode 136: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -260, Pepsi Profit: 380
# Episode 137: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -265, Pepsi Profit: 375
# Episode 138: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -275, Pepsi Profit: 385
# Episode 139: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -280, Pepsi Profit: 380
# Episode 140: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -290, Pepsi Profit: 390
# Episode 141: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -295, Pepsi Profit: 385
# Episode 142: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -290, Pepsi Profit: 390
# Episode 143: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -285, Pepsi Profit: 395
# Episode 144: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -280, Pepsi Profit: 400
# Episode 145: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -275, Pepsi Profit: 405
# Episode 146: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -270, Pepsi Profit: 410
# Episode 147: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -265, Pepsi Profit: 415
# Episode 148: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -260, Pepsi Profit: 420
# Episode 149: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -255, Pepsi Profit: 425
# Episode 150: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -265, Pepsi Profit: 435
# Episode 151: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -275, Pepsi Profit: 445
# Episode 152: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -285, Pepsi Profit: 455
# Episode 153: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -295, Pepsi Profit: 465
# Episode 154: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -300, Pepsi Profit: 460
# Episode 155: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -310, Pepsi Profit: 470
# Episode 156: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -315, Pepsi Profit: 465
# Episode 157: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -325, Pepsi Profit: 475
# Episode 158: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -330, Pepsi Profit: 470
# Episode 159: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -340, Pepsi Profit: 480
# Episode 160: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -345, Pepsi Profit: 475
# Episode 161: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -355, Pepsi Profit: 485
# Episode 162: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -360, Pepsi Profit: 480
# Episode 163: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -370, Pepsi Profit: 490
# Episode 164: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -375, Pepsi Profit: 485
# Episode 165: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -385, Pepsi Profit: 495
# Episode 166: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -390, Pepsi Profit: 490
# Episode 167: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -400, Pepsi Profit: 500
# Episode 168: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -405, Pepsi Profit: 495
# Episode 169: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -415, Pepsi Profit: 505
# Episode 170: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -420, Pepsi Profit: 500
# Episode 171: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -425, Pepsi Profit: 495
# Episode 172: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -435, Pepsi Profit: 505
# Episode 173: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: -425, Pepsi Profit: 495
# Episode 174: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -430, Pepsi Profit: 490
# Episode 175: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: -420, Pepsi Profit: 480
# Episode 176: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: -410, Pepsi Profit: 470
# Episode 177: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -415, Pepsi Profit: 465
# Episode 178: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: -405, Pepsi Profit: 455
# Episode 179: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -410, Pepsi Profit: 450
# Episode 180: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: -400, Pepsi Profit: 440
# Episode 181: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -405, Pepsi Profit: 435
# Episode 182: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -400, Pepsi Profit: 440
# Episode 183: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -395, Pepsi Profit: 445
# Episode 184: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -390, Pepsi Profit: 450
# Episode 185: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -385, Pepsi Profit: 455
# Episode 186: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -380, Pepsi Profit: 460
# Episode 187: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -375, Pepsi Profit: 465
# Episode 188: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -370, Pepsi Profit: 470
# Episode 189: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -365, Pepsi Profit: 475
# Episode 190: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -360, Pepsi Profit: 480
# Episode 191: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -370, Pepsi Profit: 490
# Episode 192: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -380, Pepsi Profit: 500
# Episode 193: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -390, Pepsi Profit: 510
# Episode 194: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -400, Pepsi Profit: 520
# Episode 195: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -410, Pepsi Profit: 530
# Episode 196: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -415, Pepsi Profit: 525
# Episode 197: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -425, Pepsi Profit: 535
# Episode 198: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -430, Pepsi Profit: 530
# Episode 199: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -440, Pepsi Profit: 540
# Episode 200: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -445, Pepsi Profit: 535
# Episode 201: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -440, Pepsi Profit: 540
# Episode 202: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -435, Pepsi Profit: 545
# Episode 203: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -430, Pepsi Profit: 550
# Episode 204: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -425, Pepsi Profit: 555
# Episode 205: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -420, Pepsi Profit: 560
# Episode 206: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -415, Pepsi Profit: 565
# Episode 207: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -410, Pepsi Profit: 570
# Episode 208: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -405, Pepsi Profit: 575
# Episode 209: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -400, Pepsi Profit: 580
# Episode 210: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -395, Pepsi Profit: 585
# Episode 211: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -390, Pepsi Profit: 590
# Episode 212: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -385, Pepsi Profit: 595
# Episode 213: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -380, Pepsi Profit: 600
# Episode 214: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -375, Pepsi Profit: 605
# Episode 215: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -370, Pepsi Profit: 610
# Episode 216: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -365, Pepsi Profit: 615
# Episode 217: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: -355, Pepsi Profit: 605
# Episode 218: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: -345, Pepsi Profit: 595
# Episode 219: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: -335, Pepsi Profit: 585
# Episode 220: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: -325, Pepsi Profit: 575
# Episode 221: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: -315, Pepsi Profit: 565
# Episode 222: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: -305, Pepsi Profit: 555
# Episode 223: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: -295, Pepsi Profit: 545
# Episode 224: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: -285, Pepsi Profit: 535
# Episode 225: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: -275, Pepsi Profit: 525
# Episode 226: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -280, Pepsi Profit: 520
# Episode 227: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: -270, Pepsi Profit: 510
# Episode 228: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -275, Pepsi Profit: 505
# Episode 229: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: -265, Pepsi Profit: 495
# Episode 230: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: -255, Pepsi Profit: 485
# Episode 231: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -260, Pepsi Profit: 480
# Episode 232: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: -250, Pepsi Profit: 470
# Episode 233: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -255, Pepsi Profit: 465
# Episode 234: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: -245, Pepsi Profit: 455
# Episode 235: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -250, Pepsi Profit: 450
# Episode 236: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -245, Pepsi Profit: 455
# Episode 237: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -240, Pepsi Profit: 460
# Episode 238: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -235, Pepsi Profit: 465
# Episode 239: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -230, Pepsi Profit: 470
# Episode 240: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -225, Pepsi Profit: 475
# Episode 241: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -220, Pepsi Profit: 480
# Episode 242: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -215, Pepsi Profit: 485
# Episode 243: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -210, Pepsi Profit: 490
# Episode 244: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -205, Pepsi Profit: 495
# Episode 245: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -200, Pepsi Profit: 500
# Episode 246: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -195, Pepsi Profit: 505
# Episode 247: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -190, Pepsi Profit: 510
# Episode 248: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: -180, Pepsi Profit: 500
# Episode 249: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: -170, Pepsi Profit: 490
# Episode 250: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: -160, Pepsi Profit: 480
# Episode 251: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: -150, Pepsi Profit: 470
# Episode 252: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: -140, Pepsi Profit: 460
# Episode 253: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: -130, Pepsi Profit: 450
# Episode 254: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -135, Pepsi Profit: 445
# Episode 255: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: -125, Pepsi Profit: 435
# Episode 256: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -130, Pepsi Profit: 430
# Episode 257: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: -120, Pepsi Profit: 420
# Episode 258: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -125, Pepsi Profit: 415
# Episode 259: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: -115, Pepsi Profit: 405
# Episode 260: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -120, Pepsi Profit: 400
# Episode 261: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: -110, Pepsi Profit: 390
# Episode 262: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -115, Pepsi Profit: 385
# Episode 263: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: -105, Pepsi Profit: 375
# Episode 264: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -110, Pepsi Profit: 370
# Episode 265: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: -100, Pepsi Profit: 360
# Episode 266: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -105, Pepsi Profit: 355
# Episode 267: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: -95, Pepsi Profit: 345
# Episode 268: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -100, Pepsi Profit: 340
# Episode 269: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: -90, Pepsi Profit: 330
# Episode 270: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -95, Pepsi Profit: 325
# Episode 271: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: -85, Pepsi Profit: 315
# Episode 272: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -90, Pepsi Profit: 310
# Episode 273: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: -80, Pepsi Profit: 300
# Episode 274: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -85, Pepsi Profit: 295
# Episode 275: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -90, Pepsi Profit: 290
# Episode 276: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: -80, Pepsi Profit: 280
# Episode 277: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -85, Pepsi Profit: 275
# Episode 278: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: -75, Pepsi Profit: 265
# Episode 279: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -80, Pepsi Profit: 260
# Episode 280: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: -70, Pepsi Profit: 250
# Episode 281: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: -60, Pepsi Profit: 240
# Episode 282: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -65, Pepsi Profit: 235
# Episode 283: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -70, Pepsi Profit: 230
# Episode 284: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: -60, Pepsi Profit: 220
# Episode 285: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -65, Pepsi Profit: 215
# Episode 286: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: -55, Pepsi Profit: 205
# Episode 287: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -60, Pepsi Profit: 200
# Episode 288: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: -50, Pepsi Profit: 190
# Episode 289: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -55, Pepsi Profit: 185
# Episode 290: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: -45, Pepsi Profit: 175
# Episode 291: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -50, Pepsi Profit: 170
# Episode 292: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: -40, Pepsi Profit: 160
# Episode 293: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -45, Pepsi Profit: 155
# Episode 294: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: -35, Pepsi Profit: 145
# Episode 295: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -40, Pepsi Profit: 140
# Episode 296: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: -30, Pepsi Profit: 130
# Episode 297: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -35, Pepsi Profit: 125
# Episode 298: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -30, Pepsi Profit: 130
# Episode 299: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -25, Pepsi Profit: 135
# Episode 300: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -20, Pepsi Profit: 140
# Episode 301: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -15, Pepsi Profit: 145
# Episode 302: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -10, Pepsi Profit: 150
# Episode 303: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -5, Pepsi Profit: 155
# Episode 304: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 0, Pepsi Profit: 160
# Episode 305: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 5, Pepsi Profit: 165
# Episode 306: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 10, Pepsi Profit: 170
# Episode 307: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 15, Pepsi Profit: 175
# Episode 308: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 20, Pepsi Profit: 180
# Episode 309: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 25, Pepsi Profit: 185
# Episode 310: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 30, Pepsi Profit: 190
# Episode 311: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 35, Pepsi Profit: 195
# Episode 312: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 40, Pepsi Profit: 200
# Episode 313: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 45, Pepsi Profit: 205
# Episode 314: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 50, Pepsi Profit: 210
# Episode 315: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 55, Pepsi Profit: 215
# Episode 316: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 60, Pepsi Profit: 220
# Episode 317: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 65, Pepsi Profit: 225
# Episode 318: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 70, Pepsi Profit: 230
# Episode 319: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 75, Pepsi Profit: 235
# Episode 320: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 80, Pepsi Profit: 240
# Episode 321: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 85, Pepsi Profit: 245
# Episode 322: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 90, Pepsi Profit: 250
# Episode 323: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 95, Pepsi Profit: 255
# Episode 324: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 100, Pepsi Profit: 260
# Episode 325: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 105, Pepsi Profit: 265
# Episode 326: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 110, Pepsi Profit: 270
# Episode 327: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 115, Pepsi Profit: 275
# Episode 328: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 120, Pepsi Profit: 280
# Episode 329: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 125, Pepsi Profit: 285
# Episode 330: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 130, Pepsi Profit: 290
# Episode 331: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 135, Pepsi Profit: 295
# Episode 332: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 140, Pepsi Profit: 300
# Episode 333: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 145, Pepsi Profit: 305
# Episode 334: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 150, Pepsi Profit: 310
# Episode 335: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 155, Pepsi Profit: 315
# Episode 336: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 160, Pepsi Profit: 320
# Episode 337: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 165, Pepsi Profit: 325
# Episode 338: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 170, Pepsi Profit: 330
# Episode 339: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 175, Pepsi Profit: 335
# Episode 340: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 180, Pepsi Profit: 340
# Episode 341: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 185, Pepsi Profit: 345
# Episode 342: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 190, Pepsi Profit: 350
# Episode 343: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 195, Pepsi Profit: 355
# Episode 344: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 200, Pepsi Profit: 360
# Episode 345: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 205, Pepsi Profit: 365
# Episode 346: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 210, Pepsi Profit: 370
# Episode 347: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 215, Pepsi Profit: 375
# Episode 348: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 220, Pepsi Profit: 380
# Episode 349: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 225, Pepsi Profit: 385
# Episode 350: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 230, Pepsi Profit: 390
# Episode 351: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 235, Pepsi Profit: 395
# Episode 352: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 240, Pepsi Profit: 400
# Episode 353: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 245, Pepsi Profit: 405
# Episode 354: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 250, Pepsi Profit: 410
# Episode 355: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 255, Pepsi Profit: 415
# Episode 356: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: 245, Pepsi Profit: 425
# Episode 357: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: 235, Pepsi Profit: 435
# Episode 358: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: 225, Pepsi Profit: 445
# Episode 359: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: 215, Pepsi Profit: 455
# Episode 360: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: 210, Pepsi Profit: 450
# Episode 361: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: 205, Pepsi Profit: 445
# Episode 362: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: 200, Pepsi Profit: 440
# Episode 363: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: 195, Pepsi Profit: 435
# Episode 364: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: 190, Pepsi Profit: 430
# Episode 365: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: 180, Pepsi Profit: 440
# Episode 366: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: 170, Pepsi Profit: 450
# Episode 367: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: 165, Pepsi Profit: 445
# Episode 368: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: 155, Pepsi Profit: 455
# Episode 369: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: 165, Pepsi Profit: 445
# Episode 370: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: 160, Pepsi Profit: 440
# Episode 371: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: 170, Pepsi Profit: 430
# Episode 372: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: 165, Pepsi Profit: 425
# Episode 373: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: 175, Pepsi Profit: 415
# Episode 374: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: 170, Pepsi Profit: 410
# Episode 375: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: 180, Pepsi Profit: 400
# Episode 376: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: 170, Pepsi Profit: 410
# Episode 377: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: 165, Pepsi Profit: 405
# Episode 378: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: 155, Pepsi Profit: 415
# Episode 379: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: 150, Pepsi Profit: 410
# Episode 380: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: 140, Pepsi Profit: 420
# Episode 381: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: 135, Pepsi Profit: 415
# Episode 382: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: 125, Pepsi Profit: 425
# Episode 383: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: 120, Pepsi Profit: 420
# Episode 384: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: 110, Pepsi Profit: 430
# Episode 385: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: 120, Pepsi Profit: 420
# Episode 386: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: 130, Pepsi Profit: 410
# Episode 387: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: 125, Pepsi Profit: 405
# Episode 388: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: 135, Pepsi Profit: 395
# Episode 389: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: 130, Pepsi Profit: 390
# Episode 390: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: 140, Pepsi Profit: 380
# Episode 391: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: 135, Pepsi Profit: 375
# Episode 392: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: 145, Pepsi Profit: 365
# Episode 393: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: 155, Pepsi Profit: 355
# Episode 394: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: 150, Pepsi Profit: 350
# Episode 395: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: 160, Pepsi Profit: 340
# Episode 396: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: 155, Pepsi Profit: 335
# Episode 397: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: 165, Pepsi Profit: 325
# Episode 398: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: 160, Pepsi Profit: 320
# Episode 399: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: 170, Pepsi Profit: 310
# Episode 400: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: 165, Pepsi Profit: 305
# Episode 401: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: 175, Pepsi Profit: 295
# Episode 402: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: 170, Pepsi Profit: 290
# Episode 403: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: 180, Pepsi Profit: 280
# Episode 404: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: 175, Pepsi Profit: 275
# Episode 405: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: 185, Pepsi Profit: 265
# Episode 406: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: 180, Pepsi Profit: 260
# Episode 407: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: 190, Pepsi Profit: 250
# Episode 408: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: 185, Pepsi Profit: 245
# Episode 409: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: 195, Pepsi Profit: 235
# Episode 410: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: 190, Pepsi Profit: 230
# Episode 411: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: 185, Pepsi Profit: 225
# Episode 412: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: 195, Pepsi Profit: 215
# Episode 413: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: 190, Pepsi Profit: 210
# Episode 414: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: 200, Pepsi Profit: 200
# Episode 415: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: 195, Pepsi Profit: 195
# Episode 416: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: 205, Pepsi Profit: 185
# Episode 417: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: 200, Pepsi Profit: 180
# Episode 418: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: 210, Pepsi Profit: 170
# Episode 419: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: 205, Pepsi Profit: 165
# Episode 420: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: 200, Pepsi Profit: 160
# Episode 421: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: 210, Pepsi Profit: 150
# Episode 422: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: 205, Pepsi Profit: 145
# Episode 423: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: 215, Pepsi Profit: 135
# Episode 424: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: 210, Pepsi Profit: 130
# Episode 425: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: 220, Pepsi Profit: 120
# Episode 426: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: 215, Pepsi Profit: 115
# Episode 427: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: 225, Pepsi Profit: 105
# Episode 428: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: 220, Pepsi Profit: 100
# Episode 429: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: 230, Pepsi Profit: 90
# Episode 430: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: 225, Pepsi Profit: 85
# Episode 431: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: 235, Pepsi Profit: 75
# Episode 432: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: 230, Pepsi Profit: 70
# Episode 433: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: 240, Pepsi Profit: 60
# Episode 434: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: 235, Pepsi Profit: 55
# Episode 435: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: 245, Pepsi Profit: 45
# Episode 436: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: 255, Pepsi Profit: 35
# Episode 437: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: 265, Pepsi Profit: 25
# Episode 438: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: 275, Pepsi Profit: 15
# Episode 439: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: 270, Pepsi Profit: 10
# Episode 440: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: 280, Pepsi Profit: 0
# Episode 441: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: 275, Pepsi Profit: -5
# Episode 442: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: 285, Pepsi Profit: -15
# Episode 443: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: 280, Pepsi Profit: -20
# Episode 444: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: 290, Pepsi Profit: -30
# Episode 445: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: 285, Pepsi Profit: -35
# Episode 446: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: 295, Pepsi Profit: -45
# Episode 447: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: 290, Pepsi Profit: -50
# Episode 448: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: 300, Pepsi Profit: -60
# Episode 449: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: 295, Pepsi Profit: -65
# Episode 450: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: 305, Pepsi Profit: -75
# Episode 451: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: 300, Pepsi Profit: -80
# Episode 452: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 305, Pepsi Profit: -75
# Episode 453: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 310, Pepsi Profit: -70
# Episode 454: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 315, Pepsi Profit: -65
# Episode 455: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 320, Pepsi Profit: -60
# Episode 456: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 325, Pepsi Profit: -55
# Episode 457: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 330, Pepsi Profit: -50
# Episode 458: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 335, Pepsi Profit: -45
# Episode 459: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 340, Pepsi Profit: -40
# Episode 460: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 345, Pepsi Profit: -35
# Episode 461: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 350, Pepsi Profit: -30
# Episode 462: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 355, Pepsi Profit: -25
# Episode 463: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 360, Pepsi Profit: -20
# Episode 464: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 365, Pepsi Profit: -15
# Episode 465: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 370, Pepsi Profit: -10
# Episode 466: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 375, Pepsi Profit: -5
# Episode 467: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 380, Pepsi Profit: 0
# Episode 468: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 385, Pepsi Profit: 5
# Episode 469: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 390, Pepsi Profit: 10
# Episode 470: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 395, Pepsi Profit: 15
# Episode 471: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 400, Pepsi Profit: 20
# Episode 472: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 405, Pepsi Profit: 25
# Episode 473: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 410, Pepsi Profit: 30
# Episode 474: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: 415, Pepsi Profit: 35
# Episode 475: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: 405, Pepsi Profit: 45
# Episode 476: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: 395, Pepsi Profit: 55
# Episode 477: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: 385, Pepsi Profit: 65
# Episode 478: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: 380, Pepsi Profit: 60
# Episode 479: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: 375, Pepsi Profit: 55
# Episode 480: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: 365, Pepsi Profit: 65
# Episode 481: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: 360, Pepsi Profit: 60
# Episode 482: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: 350, Pepsi Profit: 70
# Episode 483: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: 345, Pepsi Profit: 65
# Episode 484: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: 335, Pepsi Profit: 75
# Episode 485: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: 330, Pepsi Profit: 70
# Episode 486: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: 320, Pepsi Profit: 80
# Episode 487: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: 315, Pepsi Profit: 75
# Episode 488: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: 305, Pepsi Profit: 85
# Episode 489: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: 300, Pepsi Profit: 80
# Episode 490: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: 290, Pepsi Profit: 90
# Episode 491: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: 285, Pepsi Profit: 85
# Episode 492: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: 275, Pepsi Profit: 95
# Episode 493: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: 270, Pepsi Profit: 90
# Episode 494: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: 260, Pepsi Profit: 100
# Episode 495: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: 255, Pepsi Profit: 95
# Episode 496: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: 245, Pepsi Profit: 105
# Episode 497: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: 240, Pepsi Profit: 100
# Episode 498: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: 230, Pepsi Profit: 110
# Episode 499: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: 225, Pepsi Profit: 105
# Episode 500: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: 215, Pepsi Profit: 115
# Episode 501: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: 210, Pepsi Profit: 110
# Episode 502: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: 200, Pepsi Profit: 120
# Episode 503: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: 195, Pepsi Profit: 115
# Episode 504: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: 185, Pepsi Profit: 125
# Episode 505: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: 180, Pepsi Profit: 120
# Episode 506: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: 170, Pepsi Profit: 130
# Episode 507: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: 165, Pepsi Profit: 125
# Episode 508: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: 155, Pepsi Profit: 135
# Episode 509: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: 150, Pepsi Profit: 130
# Episode 510: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: 140, Pepsi Profit: 140
# Episode 511: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: 135, Pepsi Profit: 135
# Episode 512: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: 125, Pepsi Profit: 145
# Episode 513: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: 115, Pepsi Profit: 155
# Episode 514: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: 110, Pepsi Profit: 150
# Episode 515: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: 100, Pepsi Profit: 160
# Episode 516: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: 95, Pepsi Profit: 155
# Episode 517: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: 85, Pepsi Profit: 165
# Episode 518: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: 80, Pepsi Profit: 160
# Episode 519: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: 70, Pepsi Profit: 170
# Episode 520: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: 65, Pepsi Profit: 165
# Episode 521: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: 55, Pepsi Profit: 175
# ...
# Episode 834: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: -535, Pepsi Profit: -475
# Episode 835: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -540, Pepsi Profit: -480
# Episode 836: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: -530, Pepsi Profit: -490
# Episode 837: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -535, Pepsi Profit: -495
# Episode 838: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: -525, Pepsi Profit: -505
# Episode 839: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -530, Pepsi Profit: -510
# Episode 840: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: -520, Pepsi Profit: -520
# Episode 841: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -525, Pepsi Profit: -525
# Episode 842: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: -515, Pepsi Profit: -535
# Episode 843: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -520, Pepsi Profit: -540
# Episode 844: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: -510, Pepsi Profit: -550
# Episode 845: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -515, Pepsi Profit: -555
# Episode 846: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: -505, Pepsi Profit: -565
# Episode 847: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -510, Pepsi Profit: -570
# Episode 848: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: -500, Pepsi Profit: -580
# Episode 849: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -505, Pepsi Profit: -585
# Episode 850: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: -495, Pepsi Profit: -595
# Episode 851: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -500, Pepsi Profit: -600
# Episode 852: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: -490, Pepsi Profit: -610
# Episode 853: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: -480, Pepsi Profit: -620
# Episode 854: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -485, Pepsi Profit: -625
# Episode 855: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: -475, Pepsi Profit: -635
# Episode 856: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -480, Pepsi Profit: -640
# Episode 857: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: -470, Pepsi Profit: -650
# Episode 858: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -475, Pepsi Profit: -655
# Episode 859: Coca-Cola Action: D, Pepsi Action: C, Coca-Cola Profit: -465, Pepsi Profit: -665
# Episode 860: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -475, Pepsi Profit: -655
# Episode 861: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -485, Pepsi Profit: -645
# Episode 862: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -490, Pepsi Profit: -650
# Episode 863: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -500, Pepsi Profit: -640
# Episode 864: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -505, Pepsi Profit: -645
# Episode 865: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -515, Pepsi Profit: -635
# Episode 866: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -520, Pepsi Profit: -640
# Episode 867: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -530, Pepsi Profit: -630
# Episode 868: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -535, Pepsi Profit: -635
# Episode 869: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -545, Pepsi Profit: -625
# Episode 870: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -550, Pepsi Profit: -630
# Episode 871: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -555, Pepsi Profit: -635
# Episode 872: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -565, Pepsi Profit: -625
# Episode 873: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -570, Pepsi Profit: -630
# Episode 874: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -580, Pepsi Profit: -620
# Episode 875: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -585, Pepsi Profit: -625
# Episode 876: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -595, Pepsi Profit: -615
# Episode 877: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -600, Pepsi Profit: -620
# Episode 878: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -610, Pepsi Profit: -610
# Episode 879: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -615, Pepsi Profit: -615
# Episode 880: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -625, Pepsi Profit: -605
# Episode 881: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -630, Pepsi Profit: -610
# Episode 882: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -640, Pepsi Profit: -600
# Episode 883: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -650, Pepsi Profit: -590
# Episode 884: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -655, Pepsi Profit: -595
# Episode 885: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -665, Pepsi Profit: -585
# Episode 886: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -670, Pepsi Profit: -590
# Episode 887: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -675, Pepsi Profit: -595
# Episode 888: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -680, Pepsi Profit: -600
# Episode 889: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -690, Pepsi Profit: -590
# Episode 890: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -695, Pepsi Profit: -595
# Episode 891: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -705, Pepsi Profit: -585
# Episode 892: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -710, Pepsi Profit: -590
# Episode 893: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -715, Pepsi Profit: -595
# Episode 894: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -725, Pepsi Profit: -585
# Episode 895: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -730, Pepsi Profit: -590
# Episode 896: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -740, Pepsi Profit: -580
# Episode 897: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -745, Pepsi Profit: -585
# Episode 898: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -755, Pepsi Profit: -575
# Episode 899: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -760, Pepsi Profit: -580
# Episode 900: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -770, Pepsi Profit: -570
# Episode 901: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -775, Pepsi Profit: -575
# Episode 902: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -785, Pepsi Profit: -565
# Episode 903: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -790, Pepsi Profit: -570
# Episode 904: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -800, Pepsi Profit: -560
# Episode 905: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -805, Pepsi Profit: -565
# Episode 906: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -815, Pepsi Profit: -555
# Episode 907: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -820, Pepsi Profit: -560
# Episode 908: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -830, Pepsi Profit: -550
# Episode 909: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -835, Pepsi Profit: -555
# Episode 910: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -845, Pepsi Profit: -545
# Episode 911: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -850, Pepsi Profit: -550
# Episode 912: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -860, Pepsi Profit: -540
# Episode 913: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -865, Pepsi Profit: -545
# Episode 914: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -875, Pepsi Profit: -535
# Episode 915: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -880, Pepsi Profit: -540
# Episode 916: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -890, Pepsi Profit: -530
# Episode 917: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -895, Pepsi Profit: -535
# Episode 918: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -905, Pepsi Profit: -525
# Episode 919: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -910, Pepsi Profit: -530
# Episode 920: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -920, Pepsi Profit: -520
# Episode 921: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -930, Pepsi Profit: -510
# Episode 922: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -935, Pepsi Profit: -515
# Episode 923: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -945, Pepsi Profit: -505
# Episode 924: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -950, Pepsi Profit: -510
# Episode 925: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -960, Pepsi Profit: -500
# Episode 926: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -965, Pepsi Profit: -505
# Episode 927: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -975, Pepsi Profit: -495
# Episode 928: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -980, Pepsi Profit: -500
# Episode 929: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -990, Pepsi Profit: -490
# Episode 930: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -995, Pepsi Profit: -495
# Episode 931: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -1005, Pepsi Profit: -485
# Episode 932: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -1015, Pepsi Profit: -475
# Episode 933: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -1025, Pepsi Profit: -465
# Episode 934: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -1030, Pepsi Profit: -470
# Episode 935: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -1040, Pepsi Profit: -460
# Episode 936: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -1050, Pepsi Profit: -450
# Episode 937: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -1055, Pepsi Profit: -455
# Episode 938: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -1065, Pepsi Profit: -445
# Episode 939: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -1070, Pepsi Profit: -450
# Episode 940: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -1080, Pepsi Profit: -440
# Episode 941: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -1085, Pepsi Profit: -445
# Episode 942: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -1095, Pepsi Profit: -435
# Episode 943: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -1100, Pepsi Profit: -440
# Episode 944: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -1110, Pepsi Profit: -430
# Episode 945: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -1115, Pepsi Profit: -435
# Episode 946: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -1125, Pepsi Profit: -425
# Episode 947: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -1130, Pepsi Profit: -430
# Episode 948: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -1140, Pepsi Profit: -420
# Episode 949: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -1145, Pepsi Profit: -425
# Episode 950: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -1155, Pepsi Profit: -415
# Episode 951: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -1160, Pepsi Profit: -420
# Episode 952: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -1170, Pepsi Profit: -410
# Episode 953: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -1175, Pepsi Profit: -415
# Episode 954: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -1185, Pepsi Profit: -405
# Episode 955: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -1190, Pepsi Profit: -410
# Episode 956: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -1195, Pepsi Profit: -415
# Episode 957: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -1205, Pepsi Profit: -405
# Episode 958: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -1210, Pepsi Profit: -410
# Episode 959: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -1220, Pepsi Profit: -400
# Episode 960: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -1225, Pepsi Profit: -405
# Episode 961: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -1235, Pepsi Profit: -395
# Episode 962: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -1240, Pepsi Profit: -400
# Episode 963: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -1235, Pepsi Profit: -395
# Episode 964: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -1230, Pepsi Profit: -390
# Episode 965: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -1225, Pepsi Profit: -385
# Episode 966: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -1235, Pepsi Profit: -375
# Episode 967: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -1245, Pepsi Profit: -365
# Episode 968: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -1250, Pepsi Profit: -370
# Episode 969: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -1260, Pepsi Profit: -360
# Episode 970: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -1265, Pepsi Profit: -365
# Episode 971: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -1275, Pepsi Profit: -355
# Episode 972: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -1280, Pepsi Profit: -360
# Episode 973: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -1290, Pepsi Profit: -350
# Episode 974: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -1295, Pepsi Profit: -355
# Episode 975: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -1305, Pepsi Profit: -345
# Episode 976: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -1315, Pepsi Profit: -335
# Episode 977: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -1320, Pepsi Profit: -340
# Episode 978: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -1330, Pepsi Profit: -330
# Episode 979: Coca-Cola Action: C, Pepsi Action: D, Coca-Cola Profit: -1340, Pepsi Profit: -320
# Episode 980: Coca-Cola Action: D, Pepsi Action: D, Coca-Cola Profit: -1345, Pepsi Profit: -325
# Episode 981: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -1340, Pepsi Profit: -320
# Episode 982: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -1335, Pepsi Profit: -315
# Episode 983: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -1330, Pepsi Profit: -310
# Episode 984: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -1325, Pepsi Profit: -305
# Episode 985: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -1320, Pepsi Profit: -300
# Episode 986: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -1315, Pepsi Profit: -295
# Episode 987: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -1310, Pepsi Profit: -290
# Episode 988: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -1305, Pepsi Profit: -285
# Episode 989: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -1300, Pepsi Profit: -280
# Episode 990: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -1295, Pepsi Profit: -275
# Episode 991: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -1290, Pepsi Profit: -270
# Episode 992: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -1285, Pepsi Profit: -265
# Episode 993: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -1280, Pepsi Profit: -260
# Episode 994: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -1275, Pepsi Profit: -255
# Episode 995: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -1270, Pepsi Profit: -250
# Episode 996: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -1265, Pepsi Profit: -245
# Episode 997: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -1260, Pepsi Profit: -240
# Episode 998: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -1255, Pepsi Profit: -235
# Episode 999: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -1250, Pepsi Profit: -230
# Episode 1000: Coca-Cola Action: C, Pepsi Action: C, Coca-Cola Profit: -1245, Pepsi Profit: -225
# Coca-Cola Q-values: {(): {'C': 9.53895197253824, 'D': 0}}
# Pepsi Q-values: {(): {'C': 10.063909915084798, 'D': 0}}
# Coca-Cola Wins: 155
# Pepsi Wins: 818

# %%
import numpy as np
import random
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from collections import deque

class DQNAgent:
    def __init__(self, state_size, action_size, learning_rate=0.001, discount_factor=0.95, epsilon=1.0, epsilon_decay=0.995, epsilon_min=0.01):
        self.state_size = state_size
        self.action_size = action_size
        self.learning_rate = learning_rate
        self.discount_factor = discount_factor
        self.epsilon = epsilon
        self.epsilon_decay = epsilon_decay
        self.epsilon_min = epsilon_min
        self.memory = deque(maxlen=2000)
        self.model = self._build_model()
        self.wins = 0  # Initialize win count to zero

    def _build_model(self):
        model = Sequential()
        model.add(Dense(24, input_dim=self.state_size, activation='relu'))
        model.add(Dense(24, activation='relu'))
        model.add(Dense(self.action_size, activation='linear'))
        model.compile(loss='mse', optimizer=tf.keras.optimizers.Adam(learning_rate=self.learning_rate))
        return model

    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def choose_action(self, state):
        if np.random.rand() <= self.epsilon:
            return random.randrange(self.action_size)
        else:
            return np.argmax(self.model.predict(state)[0])

    def replay(self, batch_size):
        minibatch = random.sample(self.memory, batch_size)
        for state, action, reward, next_state, done in minibatch:
            target = reward
            if not done:
                target = reward + self.discount_factor * np.amax(self.model.predict(next_state)[0])
            target_f = self.model.predict(state)
            target_f[0][action] = target
            self.model.fit(state, target_f, epochs=1, verbose=0)
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

def simulate_competition(agent1, agent2, num_episodes=1000):
    agent1_wins = 0
    agent2_wins = 0

    for episode in range(num_episodes):
        state1 = np.array([[random.uniform(0, 1)]])  # State representing the action of agent1
        state2 = np.array([[random.uniform(0, 1)]])  # State representing the action of agent2

        action1 = agent1.choose_action(state1)
        action2 = agent2.choose_action(state2)

        reward1, reward2 = 0, 0

        if action1 == action2:  # Both agents cooperate or both defect
            if action1 == 1:  # Both cooperate
                reward1, reward2 = 5, 5
            else:  # Both defect
                reward1, reward2 = -5, -5
        else:  # One agent cooperates, the other defects
            if action1 == 1:  # Agent1 cooperates, agent2 defects
                reward1, reward2 = -10, 10
                agent2_wins += 1
            else:  # Agent1 defects, agent2 cooperates
                reward1, reward2 = 10, -10
                agent1_wins += 1

        next_state1 = np.array([[random.uniform(0, 1)]])
        next_state2 = np.array([[random.uniform(0, 1)]])

        agent1.remember(state1, action1, reward1, next_state1, False)
        agent2.remember(state2, action2, reward2, next_state2, False)

        state1, state2 = next_state1, next_state2

        if episode > 32:
            agent1.replay(32)
            agent2.replay(32)

        print(f"Episode {episode + 1}/{num_episodes}, Agent 1 Profit: {reward1}, Agent 2 Profit: {reward2}")

    return agent1_wins, agent2_wins

# Create DQNAgents
agent1 = DQNAgent(state_size=1, action_size=2)
agent2 = DQNAgent(state_size=1, action_size=2)

# Simulate the competition
agent1_wins, agent2_wins = simulate_competition(agent1, agent2, num_episodes=100)

print("Agent 1 Wins:", agent1_wins)
print("Agent 2 Wins:", agent2_wins)
# Out:
# Streaming output truncated to the last 5000 lines.
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 44ms/step
# Episode 62/100, Agent 1 Profit: 5, Agent 2 Profit: 5
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 39ms/step
# Episode 63/100, Agent 1 Profit: 10, Agent 2 Profit: -10
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 47ms/step
# Episode 64/100, Agent 1 Profit: 10, Agent 2 Profit: -10
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 33ms/step
# Episode 65/100, Agent 1 Profit: -10, Agent 2 Profit: 10
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# Episode 66/100, Agent 1 Profit: -10, Agent 2 Profit: 10
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# Episode 67/100, Agent 1 Profit: 5, Agent 2 Profit: 5
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 22ms/step
# Episode 68/100, Agent 1 Profit: -5, Agent 2 Profit: -5
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# ...
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# Episode 98/100, Agent 1 Profit: -5, Agent 2 Profit: -5
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# Episode 99/100, Agent 1 Profit: -5, Agent 2 Profit: -5
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 27ms/step
# Episode 100/100, Agent 1 Profit: -5, Agent 2 Profit: -5
# Agent 1 Wins: 21
# Agent 2 Wins: 20
